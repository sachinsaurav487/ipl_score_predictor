# %% [markdown]
# ## First Innings Score Prediction

# %%
# Importing essential libraries
import pandas as pd
import pickle

# Loading the dataset
df = pd.read_csv('ipl.csv')

# %%
df.head()
# Out:
#    mid        date                  venue               bat_team  \
# 0    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 1    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 2    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 3    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
# 4    1  2008-04-18  M Chinnaswamy Stadium  Kolkata Knight Riders
#
#                      bowl_team      batsman   bowler  runs  wickets  overs  \
# 0  Royal Challengers Bangalore   SC Ganguly  P Kumar     1        0    0.1
# 1  Royal Challengers Bangalore  BB McCullum  P Kumar     1        0    0.2
# 2  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.2
# 3  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.3
# 4  Royal Challengers Bangalore  BB McCullum  P Kumar     2        0    0.4
#
#    runs_last_5  wickets_last_5  striker  non-striker  total
# 0            1               0        0            0    222
# 1            1               0        0            0    222
# 2            2               0        0            0    222
# 3            2               0        0            0    222
# 4            2               0        0            0    222

# %%
# --- Data Cleaning ---
# Removing unwanted columns
columns_to_remove = ['mid', 'venue', 'batsman', 'bowler', 'striker', 'non-striker']
df.drop(labels=columns_to_remove, axis=1, inplace=True)

# %%
df.head()
# Out:
#          date               bat_team                    bowl_team  runs  \
# 0  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 1  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore     1
# 2  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore     2
# 3  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore     2
# 4  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore     2
#
#    wickets  overs  runs_last_5  wickets_last_5  total
# 0        0    0.1            1               0    222
# 1        0    0.2            1               0    222
# 2        0    0.2            2               0    222
# 3        0    0.3            2               0    222
# 4        0    0.4            2               0    222

# %%
df['bat_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
#        'Mumbai Indians', 'Deccan Chargers', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Delhi Daredevils',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Rising Pune Supergiants', 'Gujarat Lions',
#        'Rising Pune Supergiant'], dtype=object)

# %%
# Keeping only consistent teams
consistent_teams = ['Kolkata Knight Riders', 'Chennai Super Kings', 'Rajasthan Royals',
                    'Mumbai Indians', 'Kings XI Punjab', 'Royal Challengers Bangalore',
                    'Delhi Daredevils', 'Sunrisers Hyderabad']

# %%
df = df[(df['bat_team'].isin(consistent_teams)) & (df['bowl_team'].isin(consistent_teams))]

# %%
# Removing the first 5 overs data in every match
df = df[df['overs']>=5.0]

# %%
df.head()
# Out:
#           date               bat_team                    bowl_team  runs  \
# 32  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore    61
# 33  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore    61
# 34  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore    61
# 35  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore    61
# 36  2008-04-18  Kolkata Knight Riders  Royal Challengers Bangalore    61
#
#     wickets  overs  runs_last_5  wickets_last_5  total
# 32        0    5.1           59               0    222
# 33        1    5.2           59               1    222
# 34        1    5.3           59               1    222
# 35        1    5.4           59               1    222
# 36        1    5.5           58               1    222

# %%
print(df['bat_team'].unique())
print(df['bowl_team'].unique())
# Out:
# ['Kolkata Knight Riders' 'Chennai Super Kings' 'Rajasthan Royals'
#  'Mumbai Indians' 'Kings XI Punjab' 'Royal Challengers Bangalore'
#  'Delhi Daredevils' 'Sunrisers Hyderabad']
# ['Royal Challengers Bangalore' 'Kings XI Punjab' 'Delhi Daredevils'
#  'Rajasthan Royals' 'Mumbai Indians' 'Chennai Super Kings'
#  'Kolkata Knight Riders' 'Sunrisers Hyderabad']

# %%
# Converting the column 'date' from string into datetime object
from datetime import datetime
df['date'] = df['date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
# --- Data Preprocessing ---
# Converting categorical features using OneHotEncoding method
encoded_df = pd.get_dummies(data=df, columns=['bat_team', 'bowl_team'])

# %%
encoded_df.head()
# Out:
#          date  runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 32 2008-04-18    61        0    5.1           59               0    222
# 33 2008-04-18    61        1    5.2           59               1    222
# 34 2008-04-18    61        1    5.3           59               1    222
# 35 2008-04-18    61        1    5.4           59               1    222
# 36 2008-04-18    61        1    5.5           58               1    222
#
#     bat_team_Chennai Super Kings  bat_team_Delhi Daredevils  \
# 32                             0                          0
# 33                             0                          0
# 34                             0                          0
# 35                             0                          0
# 36                             0                          0
#
#     bat_team_Kings XI Punjab  ...  bat_team_Royal Challengers Bangalore  \
# 32                         0  ...                                     0
# 33                         0  ...                                     0
# 34                         0  ...                                     0
# 35                         0  ...                                     0
# 36                         0  ...                                     0
#
#     bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings  \
# 32                             0                              0
# 33                             0                              0
# 34                             0                              0
# 35                             0                              0
# 36                             0                              0
#
#     bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab  \
# 32                           0                          0
# 33                           0                          0
# 34                           0                          0
# 35                           0                          0
# 36                           0                          0
#
#     bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians  \
# 32                                0                         0
# 33                                0                         0
# 34                                0                         0
# 35                                0                         0
# 36                                0                         0
#
#     bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore  \
# 32                           0                                      1
# 33                           0                                      1
# 34                           0                                      1
# 35                           0                                      1
# 36                           0                                      1
#
#     bowl_team_Sunrisers Hyderabad
# 32                              0
# 33                              0
# 34                              0
# 35                              0
# 36                              0
#
# [5 rows x 23 columns]

# %%
encoded_df.head()
# Out:
#          date  runs  wickets  overs  runs_last_5  wickets_last_5  total  \
# 32 2008-04-18    61        0    5.1           59               0    222
# 33 2008-04-18    61        1    5.2           59               1    222
# 34 2008-04-18    61        1    5.3           59               1    222
# 35 2008-04-18    61        1    5.4           59               1    222
# 36 2008-04-18    61        1    5.5           58               1    222
#
#     bat_team_Chennai Super Kings  bat_team_Delhi Daredevils  \
# 32                             0                          0
# 33                             0                          0
# 34                             0                          0
# 35                             0                          0
# 36                             0                          0
#
#     bat_team_Kings XI Punjab  ...  bat_team_Royal Challengers Bangalore  \
# 32                         0  ...                                     0
# 33                         0  ...                                     0
# 34                         0  ...                                     0
# 35                         0  ...                                     0
# 36                         0  ...                                     0
#
#     bat_team_Sunrisers Hyderabad  bowl_team_Chennai Super Kings  \
# 32                             0                              0
# 33                             0                              0
# 34                             0                              0
# 35                             0                              0
# 36                             0                              0
#
#     bowl_team_Delhi Daredevils  bowl_team_Kings XI Punjab  \
# 32                           0                          0
# 33                           0                          0
# 34                           0                          0
# 35                           0                          0
# 36                           0                          0
#
#     bowl_team_Kolkata Knight Riders  bowl_team_Mumbai Indians  \
# 32                                0                         0
# 33                                0                         0
# 34                                0                         0
# 35                                0                         0
# 36                                0                         0
#
#     bowl_team_Rajasthan Royals  bowl_team_Royal Challengers Bangalore  \
# 32                           0                                      1
# 33                           0                                      1
# 34                           0                                      1
# 35                           0                                      1
# 36                           0                                      1
#
#     bowl_team_Sunrisers Hyderabad
# 32                              0
# 33                              0
# 34                              0
# 35                              0
# 36                              0
#
# [5 rows x 23 columns]

# %%
encoded_df.columns
# Out:
# Index(['date', 'runs', 'wickets', 'overs', 'runs_last_5', 'wickets_last_5',
#        'total', 'bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils',
#        'bat_team_Kings XI Punjab', 'bat_team_Kolkata Knight Riders',
#        'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
#        'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
#        'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils',
#        'bowl_team_Kings XI Punjab', 'bowl_team_Kolkata Knight Riders',
#        'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
#        'bowl_team_Royal Challengers Bangalore',
#        'bowl_team_Sunrisers Hyderabad'],
#       dtype='object')

# %%
# Rearranging the columns
encoded_df = encoded_df[['date', 'bat_team_Chennai Super Kings', 'bat_team_Delhi Daredevils', 'bat_team_Kings XI Punjab',
              'bat_team_Kolkata Knight Riders', 'bat_team_Mumbai Indians', 'bat_team_Rajasthan Royals',
              'bat_team_Royal Challengers Bangalore', 'bat_team_Sunrisers Hyderabad',
              'bowl_team_Chennai Super Kings', 'bowl_team_Delhi Daredevils', 'bowl_team_Kings XI Punjab',
              'bowl_team_Kolkata Knight Riders', 'bowl_team_Mumbai Indians', 'bowl_team_Rajasthan Royals',
              'bowl_team_Royal Challengers Bangalore', 'bowl_team_Sunrisers Hyderabad',
              'overs', 'runs', 'wickets', 'runs_last_5', 'wickets_last_5', 'total']]

# %%
# Splitting the data into train and test set
X_train = encoded_df.drop(labels='total', axis=1)[encoded_df['date'].dt.year <= 2016]
X_test = encoded_df.drop(labels='total', axis=1)[encoded_df['date'].dt.year >= 2017]

# %%
y_train = encoded_df[encoded_df['date'].dt.year <= 2016]['total'].values
y_test = encoded_df[encoded_df['date'].dt.year >= 2017]['total'].values

# %%
# Removing the 'date' column
X_train.drop(labels='date', axis=True, inplace=True)
X_test.drop(labels='date', axis=True, inplace=True)

# %%
# --- Model Building ---
# Linear Regression Model
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Creating a pickle file for the classifier
filename = 'first-innings-score-lr-model.pkl'
pickle.dump(regressor, open(filename, 'wb'))

# %%
#importing ml algo's
from sklearn.linear_model  import Ridge,Lasso,RidgeCV, LassoCV, ElasticNet, ElasticNetCV, LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.linear_model import BayesianRidge
from lightgbm import LGBMRegressor

# %%
Reg=[LinearRegression(),Ridge(),Lasso(),RidgeCV(),LassoCV(),ElasticNet(),ElasticNetCV(),DecisionTreeRegressor(),RandomForestRegressor(),XGBRegressor(),LGBMRegressor(),KNeighborsRegressor(),SVR(),BayesianRidge()]

# %%
#checking scores while training with different ml algo's 
for i in Reg:
    model=i
    model.fit(X_train,y_train)
    #y_pred_train=model.predict(xa_train)
    #y_pred_test = model.predict(xa_test)
    print('Training Score for *****************' ,i ,'model is      =   ',end="")
    print(model.score(X_train,y_train))
    print('Test Score for ************************' ,i ,'model is      =  ',end="")
    print(model.score(X_test,y_test))
    print()
    print()
    print()
    print()
# Out:
# Training Score for ***************** LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) model is      =   0.6502132284850832
# Test Score for ************************ LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) model is      =  0.7522274447953539
#
#
#
#
# Training Score for ***************** Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001) model is      =   0.6502133807548146
# Test Score for ************************ Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001) model is      =  0.7522627797893786
#
#
#
#
# Training Score for ***************** Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False) model is      =   0.638547675966879
# Test Score for ************************ Lasso(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False) model is      =  0.7410397471190056
#
#
#
#
# Training Score for ***************** RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=None, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring=None, store_cv_values=False) model is      =   0.650213335265754
# Test Score for ************************ RidgeCV(alphas=array([ 0.1,  1. , 10. ]), cv=None, fit_intercept=True,
#         gcv_mode=None, normalize=False, scoring=None, store_cv_values=False) model is      =  0.752257563487693
#
#
#
#
# Training Score for ***************** LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False) model is      =   0.6390449823622812
# Test Score for ************************ LassoCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#         max_iter=1000, n_alphas=100, n_jobs=None, normalize=False,
#         positive=False, precompute='auto', random_state=None,
#         selection='cyclic', tol=0.0001, verbose=False) model is      =  0.7424792632744397
#
#
#
#
# Training Score for ***************** ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False) model is      =   0.6347481877291821
# Test Score for ************************ ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False) model is      =  0.7306010048337253
#
#
#
#
# Training Score for ***************** ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#              l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=None,
#              normalize=False, positive=False, precompute='auto',
#              random_state=None, selection='cyclic', tol=0.0001, verbose=0) model is      =   0.6354744205680525
# Test Score for ************************ ElasticNetCV(alphas=None, copy_X=True, cv=None, eps=0.001, fit_intercept=True,
#              l1_ratio=0.5, max_iter=1000, n_alphas=100, n_jobs=None,
#              normalize=False, positive=False, precompute='auto',
#              random_state=None, selection='cyclic', tol=0.0001, verbose=0) model is      =  0.7318576944982493
#
#
#
#
# Training Score for ***************** DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') model is      =   0.9998567447518953
# Test Score for ************************ DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') model is      =  0.4784729833795848
#
#
#
#
# Training Score for ***************** RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) model is      =   0.9922587553557656
# Test Score for ************************ RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False) model is      =  0.6725043570211215
#
#
#
#
# [10:11:46] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Training Score for ***************** XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1) model is      =   0.6844639357148385
# Test Score for ************************ XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1) model is      =  0.7155898276260086
#
#
#
#
# Training Score for ***************** LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0) model is      =   0.8042317600283377
# Test Score for ************************ LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=None, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0) model is      =  0.7259997891782825
#
#
#
#
# Training Score for ***************** KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform') model is      =   0.8843083153618684
# Test Score for ************************ KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                     weights='uniform') model is      =  0.6047516212009467
#
#
#
#
# Training Score for ***************** SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) model is      =   0.5811585311962435
# Test Score for ************************ SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1, gamma='scale',
#     kernel='rbf', max_iter=-1, shrinking=True, tol=0.001, verbose=False) model is      =  0.643444370462407
#
#
#
#
# Training Score for ***************** BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False) model is      =   0.6502125255501772
# Test Score for ************************ BayesianRidge(alpha_1=1e-06, alpha_2=1e-06, alpha_init=None,
#               compute_score=False, copy_X=True, fit_intercept=True,
#               lambda_1=1e-06, lambda_2=1e-06, lambda_init=None, n_iter=300,
#               normalize=False, tol=0.001, verbose=False) model is      =  0.7522377816889065

# %%
#as we saw above in xgboost algo we getting better score than other model so we should now do hypertuning over it.
from sklearn.model_selection import GridSearchCV
param_grid8={
   
    'learning_rate':[0.01,0.1,1],
    'n_estimators':[300],
    'max_depth': [1,2,3,4],
    'min_child_samples':range(10,30)
    }

grid= GridSearchCV(LGBMRegressor(),param_grid8, verbose=3)

grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300, score=0.402, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.6s remaining:    0.0s
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=10, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300, score=0.379, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=11, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=12, n_estimators=300, score=0.386, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300, score=0.402, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=13, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300, score=0.379, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300, score=0.351, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=14, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300, score=0.351, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=15, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=16, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=17, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=18, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=19, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300, score=0.351, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=20, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300, score=0.415, total=   0.5s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300, score=0.351, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=21, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300, score=0.402, total=   0.5s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300, score=0.379, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=22, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=23, n_estimators=300, score=0.386, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=24, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=25, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=26, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=27, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300, score=0.415, total=   0.4s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=28, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300, score=0.402, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300, score=0.379, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300, score=0.415, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300, score=0.351, total=   0.3s
# [CV] learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=1, min_child_samples=29, n_estimators=300, score=0.386, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=10, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=11, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=12, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300, score=0.534, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=13, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300, score=0.429, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=14, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=15, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300, score=0.534, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=16, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=17, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300, score=0.493, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300, score=0.534, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300, score=0.429, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=18, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300, score=0.534, total=   0.5s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=19, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=20, n_estimators=300, score=0.521, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=21, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=22, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=23, n_estimators=300, score=0.521, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300, score=0.534, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300, score=0.429, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=24, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300, score=0.493, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=25, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300, score=0.534, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300, score=0.429, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=26, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=27, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300, score=0.542, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300, score=0.534, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=28, n_estimators=300, score=0.521, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300, score=0.542, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300, score=0.493, total=   0.4s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300, score=0.534, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300, score=0.429, total=   0.3s
# [CV] learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=2, min_child_samples=29, n_estimators=300, score=0.521, total=   0.3s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=10, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=11, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=12, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=13, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=14, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=15, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300, score=0.471, total=   0.5s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=16, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300, score=0.559, total=   0.5s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300, score=0.588, total=   0.6s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300, score=0.471, total=   0.5s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=17, n_estimators=300, score=0.582, total=   0.6s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300, score=0.588, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=18, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300, score=0.609, total=   0.5s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300, score=0.589, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=19, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300, score=0.589, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300, score=0.471, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=20, n_estimators=300, score=0.582, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300, score=0.609, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300, score=0.559, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300, score=0.589, total=   0.4s
# [CV] learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=0.01, max_depth=3, min_child_samples=21, n_estimators=300, score=0.471, total=   0.4s
# ...
# [CV]  learning_rate=1, max_depth=4, min_child_samples=13, n_estimators=300, score=0.402, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=13, n_estimators=300, score=0.296, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=13, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=13, n_estimators=300, score=0.370, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300, score=0.468, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300, score=0.480, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300, score=0.377, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300, score=0.260, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=14, n_estimators=300, score=0.346, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300, score=0.449, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300, score=0.448, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300, score=0.386, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300, score=0.243, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=15, n_estimators=300, score=0.311, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300, score=0.432, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300, score=0.494, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300, score=0.391, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300, score=0.274, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=16, n_estimators=300, score=0.357, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300, score=0.447, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300, score=0.465, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300, score=0.420, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300, score=0.301, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=17, n_estimators=300, score=0.336, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300, score=0.427, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300, score=0.496, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300, score=0.379, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300, score=0.292, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=18, n_estimators=300, score=0.300, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300, score=0.432, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300, score=0.499, total=   0.7s
# [CV] learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300, score=0.402, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300, score=0.267, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=19, n_estimators=300, score=0.324, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300, score=0.447, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300, score=0.463, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300, score=0.464, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300, score=0.309, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=20, n_estimators=300, score=0.323, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300, score=0.444, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300, score=0.468, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300, score=0.414, total=   0.8s
# [CV] learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300, score=0.301, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=21, n_estimators=300, score=0.338, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300, score=0.477, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300, score=0.492, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300, score=0.415, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300, score=0.292, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=22, n_estimators=300, score=0.369, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300, score=0.470, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300, score=0.481, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300, score=0.408, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300, score=0.323, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=23, n_estimators=300, score=0.366, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300, score=0.456, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300, score=0.472, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300, score=0.399, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300, score=0.300, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=24, n_estimators=300, score=0.386, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300, score=0.488, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300, score=0.455, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300, score=0.412, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300, score=0.288, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=25, n_estimators=300, score=0.349, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300, score=0.415, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300, score=0.495, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300, score=0.348, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300, score=0.321, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=26, n_estimators=300, score=0.335, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300, score=0.429, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300, score=0.476, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300, score=0.408, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300, score=0.289, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=27, n_estimators=300, score=0.329, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300, score=0.461, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300, score=0.489, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300, score=0.453, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300, score=0.313, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=28, n_estimators=300, score=0.331, total=   0.7s
# [CV] learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300, score=0.449, total=   0.7s
# [CV] learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300, score=0.466, total=   0.7s
# [CV] learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300, score=0.368, total=   0.6s
# [CV] learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300, score=0.301, total=   0.5s
# [CV] learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300
# [CV]  learning_rate=1, max_depth=4, min_child_samples=29, n_estimators=300, score=0.356, total=   0.6s
# [Parallel(n_jobs=1)]: Done 1200 out of 1200 | elapsed:  8.5min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=LGBMRegressor(boosting_type='gbdt', class_weight=None,
#                                      colsample_bytree=1.0,
#                                      importance_type='split', learning_rate=0.1,
#                                      max_depth=-1, min_child_samples=20,
#                                      min_child_weight=0.001, min_split_gain=0.0,
#                                      n_estimators=100, n_jobs=-1, num_leaves=31,
#                                      objective=None, random_state=None,
#                                      reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                                      subsample=1.0, subsample_for_bin=200000,
#                                      subsample_freq=0),
#              iid='deprecated', n_jobs=None,
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'max_depth': [1, 2, 3, 4],
#                          'min_child_samples': range(10, 30),
#                          'n_estimators': [300]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# To  find the parameters giving accuracy
print(grid.best_params_)
model=grid.best_estimator_
print("train score is   ----------->    ",model.score(X_train,y_train))
print("test score is   ----------->    ",model.score(X_test,y_test))
# Out:
# {'learning_rate': 1, 'max_depth': 1, 'min_child_samples': 13, 'n_estimators': 300}
# train score is   ----------->     0.6663448129216347
# test score is   ----------->     0.755541772519361
